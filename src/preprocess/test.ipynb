# %%
import pandas as pd
from preprocess import pipeline, preprocess_x


data = pd.read_csv("../../data/train_airbnb_berlin.xls")
data = data.dropna(subset=["Price"]).reset_index(drop=True)

Y = data["Price"]
X = data.drop(columns=["Price"])


X_train = pipeline.fit_transform(X)
# Out:
# Neighborhood Group       0
# Latitude                 0
# Longitude                0
# Property Type            0
# Room Type                0
# Accomodates              0
# Bathrooms                0
# Bedrooms                 0
# Beds                     0
# Guests Included          0
# Min Nights               0
# Reviews                  0
# Overall Rating           0
# Accuracy Rating          0
# Cleanliness Rating       0
# Checkin Rating           0
# Communication Rating     0
# Location Rating          0
# Value Rating             0
# Instant Bookable         0
# Business Travel Ready    0
# Price                    0
# dtype: int64

# %%
data.head(5)
# Out:
#          Neighborhood Group  Latitude  Longitude Property Type  \
# 0                    Pankow  52.54652   13.41792     Apartment
# 1                    Pankow  52.56512   13.42214     Apartment
# 2                    Pankow  52.54741   13.42521     Apartment
# 3  Friedrichshain-Kreuzberg  52.50958   13.45144     Apartment
# 4   Tempelhof - Sch̦neberg  52.44826   13.40608   Condominium
#
#          Room Type Accomodates Bathrooms Bedrooms Beds Guests Included  ...  \
# 0     Private room           2       1.0      1.0  1.0               1  ...
# 1  Entire home/apt           2       1.0      2.0  2.0               2  ...
# 2  Entire home/apt           3       1.0      1.0  2.0               1  ...
# 3     Private room           2       1.0      1.0  1.0               1  ...
# 4     Private room           3       1.0      1.0  2.0               2  ...
#
#   Overall Rating  Accuracy Rating  Cleanliness Rating  Checkin Rating  \
# 0          100.0             10.0                10.0            10.0
# 1           90.0              9.0                 9.0            10.0
# 2          100.0             10.0                10.0            10.0
# 3          100.0             10.0                10.0            10.0
# 4           99.0             10.0                 9.0            10.0
#
#    Communication Rating  Location Rating  Value Rating  Instant Bookable  \
# 0                  10.0              9.0          10.0                 t
# 1                  10.0              9.0          10.0                 f
# 2                  10.0             10.0          10.0                 f
# 3                  10.0             10.0           9.0                 f
# 4                  10.0             10.0          10.0                 t
#
#    Business Travel Ready Price
# 0                      f  26.0
# 1                      f  41.0
# 2                      f  50.0
# 3                      f  50.0
# 4                      f  39.0
#
# [5 rows x 22 columns]

# %%
data.isna().sum()
# Out:
# Neighborhood Group       0
# Latitude                 0
# Longitude                0
# Property Type            0
# Room Type                0
# Accomodates              0
# Bathrooms                0
# Bedrooms                 0
# Beds                     0
# Guests Included          0
# Min Nights               0
# Reviews                  0
# Overall Rating           0
# Accuracy Rating          0
# Cleanliness Rating       0
# Checkin Rating           0
# Communication Rating     0
# Location Rating          0
# Value Rating             0
# Instant Bookable         0
# Business Travel Ready    0
# Price                    0
# dtype: int64

# %%
from utils import drop_useless
import numpy as np

data = drop_useless(data)

data = data.replace("*", np.nan)

# listfeatures = incomplete_columns(data, to_print=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-abcbd4d4582b> in <module>
#       2 import numpy as np
#       3
# ----> 4 data = drop_useless(data)
#       5
#       6 data = data.replace("*", np.nan)
#
# c:\Users\faust\Documents\CS\3A\SD9\Apprentissage automatique\Airbnb\src\preprocess\utils.py in drop_useless(data)
#       6 def drop_useless(data):
#       7     """Drop useless features."""
# ----> 8     data = data.drop(
#       9         columns=[
#      10             "Listing ID",
#
# c:\Users\faust\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# c:\Users\faust\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# c:\Users\faust\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# c:\Users\faust\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['Listing ID' 'Listing Name' 'Host ID' 'Host Name' 'Host Since'\n 'Is Exact Location' 'Country' 'First Review' 'Last Review' 'City'\n 'Postal Code' 'Country Code' 'neighbourhood' 'Is Superhost'] not found in axis"

# %%
from utils import drop_missing_too_high

data = drop_missing_too_high(data)

data["Property Type"] = np.where(
    data["Property Type"].isna(), "Apartment", data["Property Type"]
)

# %%
data = data.dropna(
        subset=[
            'Accomodates',
            'Bathrooms',
            'Bedrooms',
            'Beds',
            'Guests Included',
            'Min Nights',
        ]
    )

obj = set(data.select_dtypes(["object"]).columns)
na = set(data.columns[data.isna().any()].tolist())
data = data.astype({x: "float64" for x in obj.intersection(na)})

data = data.dropna(subset=['Overall Rating', 'Accuracy Rating', 'Cleanliness Rating',
                            'Checkin Rating', 'Communication Rating', 'Location Rating', 'Value Rating']).reset_index(drop=True)

# %%
data.isna().sum()
# Out:
# Neighborhood Group       0
# Latitude                 0
# Longitude                0
# Property Type            0
# Room Type                0
# Accomodates              0
# Bathrooms                0
# Bedrooms                 0
# Beds                     0
# Guests Included          0
# Min Nights               0
# Reviews                  0
# Overall Rating           0
# Accuracy Rating          0
# Cleanliness Rating       0
# Checkin Rating           0
# Communication Rating     0
# Location Rating          0
# Value Rating             0
# Instant Bookable         0
# Business Travel Ready    0
# Price                    0
# dtype: int64
